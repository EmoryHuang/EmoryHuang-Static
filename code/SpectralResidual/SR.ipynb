# %%
from SpectralResidual import SpectralResidual
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('sample.csv')
data = data['value'].to_numpy()

# %%
detector = SpectralResidual(series_window_size=12, mag_window_size=3, score_window_size=40)
result = detector.detect(data)
# Out:
# d:\Document\code\Algorithm\SpectralResidual\SpectralResidual.py:33: RuntimeWarning: invalid value encountered in true_divide
#   raw_scores = np.abs(mags - ave_mag) / safeDivisors

# %%
plt.plot(result)
